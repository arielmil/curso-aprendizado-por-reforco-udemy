# %% [markdown]
# Nesse notebook será feito uma demonstração do algorítimo de Q Learning.

# %%
# %cd ../reinforcement
# %run gridworld.py -a q -k 100 -r -0.04
# Out:
# /home/mileguir/Desktop/curso-aprendizado-por-reforco-udemy/reinforcement
#
# RUNNING 100 EPISODES
#
# BEGINNING EPISODE: 1
#
# Started in state: (0, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: -0.04
#
# Started in state: (0, 0)
# Took action: east
# Ended in state: (1, 0)
# Got reward: -0.04
#
# Started in state: (1, 0)
# Took action: south
# Ended in state: (1, 0)
# Got reward: -0.04
#
# Started in state: (1, 0)
# Took action: west
# Ended in state: (0, 0)
# Got reward: -0.04
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: -0.04
#
# Started in state: (0, 1)
# Took action: east
# Ended in state: (0, 0)
# Got reward: -0.04
#
# Started in state: (0, 0)
# Took action: north
# Ended in state: (0, 1)
# Got reward: -0.04
#
# Started in state: (0, 1)
# Took action: north
# Ended in state: (0, 2)
# Got reward: -0.04
#
# Started in state: (0, 2)
# Took action: north
# Ended in state: (0, 2)
# Got reward: -0.04
#
# ...
